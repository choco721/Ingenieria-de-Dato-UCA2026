# %% [markdown]
# # Verificación del entorno
# Notebook mínimo para confirmar que Python y las librerías base andan.
# Corré la celda de abajo: si imprime las versiones sin error, estás listo.

# %%
import sys
import pandas as pd
import duckdb

print(f'Python: {sys.version.split()[0]}')
print(f'pandas: {pd.__version__}')
print(f'duckdb: {duckdb.__version__}')
print('Entorno OK')
